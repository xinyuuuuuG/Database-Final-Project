# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/2433p4
# Out:
# /content/drive/MyDrive/2433p4

# %%
ls
# Out:
#  Medicalpremium.csv  'ML Model.ipynb'

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_recall_curve

# %% [markdown]
# ##Load Data

# %%
df = pd.read_csv("Medicalpremium.csv")

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice
# 0                         0         25000
# 1                         0         29000
# 2                         1         23000
# 3                         2         28000
# 4                         1         23000
# ..                      ...           ...
# 981                       0         15000
# 982                       3         28000
# 983                       1         29000
# 984                       1         39000
# 985                       1         15000
#
# [986 rows x 11 columns]

# %%
print(df["NumberOfMajorSurgeries"].value_counts())
# Out:
# 0    479
# 1    372
# 2    119
# 3     16
# Name: NumberOfMajorSurgeries, dtype: int64

# %%
df.dtypes
# Out:
# Age                        int64
# Diabetes                   int64
# BloodPressureProblems      int64
# AnyTransplants             int64
# AnyChronicDiseases         int64
# Height                     int64
# Weight                     int64
# KnownAllergies             int64
# HistoryOfCancerInFamily    int64
# NumberOfMajorSurgeries     int64
# PremiumPrice               int64
# dtype: object

# %% [markdown]
# ##Train-Test Split

# %%
y = df.PremiumPrice	
X = df.drop(['PremiumPrice'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ##Linear Regression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.intercept_
# Out:
# 5755.72697033457

# %%
coeff_parameter = pd.DataFrame(reg.coef_, X_train.columns, columns=['Coefficient'])
coeff_parameter
# Out:
#                          Coefficient
# Age                       322.870747
# Diabetes                 -231.664423
# BloodPressureProblems      -4.400753
# AnyTransplants           6487.195596
# AnyChronicDiseases       2549.749326
# Height                     -3.571462
# Weight                     66.080248
# KnownAllergies             47.325868
# HistoryOfCancerInFamily  1681.452833
# NumberOfMajorSurgeries   -642.595969
